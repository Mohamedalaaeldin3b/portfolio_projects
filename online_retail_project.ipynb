# %% [markdown]
# # **Online Retail Data Analysis Project**

# %% [markdown]
# # **Introduction**

# %% [markdown]
# - This dataset Online Retail Sales and Customer Data is downloaded from kaggle.com
# - Data is in tabular format(.csv file) of 9 columns and 541909 entries.
# - The dataset contains entries for invoices for each customer with timestamp, geographical location, product, quantity and price.
# - Columns are: index, InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
from scipy.interpolate import make_interp_spline

plt.style.use('fast')

# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Machine_Learning_Python/Projects/online_retail_project/online_retail.csv')

# %% [markdown]
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼

# %% [markdown]
# # **Data Exploration**

# %%
df.head()
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        541909 non-null  int64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  object
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.2+ MB

# %%
df.isnull().sum()
# Out:
# index               0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ## Index Column

# %%
df[['index']].count()
# Out:
# index    541909
# dtype: int64

# %%
pd.Series(df['index'].unique()).count()
# Out:
# 541909

# %% [markdown]
# # InvoiceNo Column

# %%
df['InvoiceNo'].value_counts()
# Out:
# 573585     1114
# 581219      749
# 581492      731
# 580729      721
# 558475      705
#            ...
# 554023        1
# 554022        1
# 554021        1
# 554020        1
# C558901       1
# Name: InvoiceNo, Length: 25900, dtype: int64

# %%
len(df['InvoiceNo'].unique())
# Out:
# 25900

# %% [markdown]
# # StockCode Column

# %%
df['StockCode'].value_counts()
# Out:
# 85123A    2313
# 22423     2203
# 85099B    2159
# 47566     1727
# 20725     1639
#           ...
# 21431        1
# 22275        1
# 17001        1
# 90187A       1
# 72759        1
# Name: StockCode, Length: 4070, dtype: int64

# %%
len(df['StockCode'].value_counts())
# Out:
# 4070

# %% [markdown]
# # Description Column

# %%
df['Description'].isnull().sum()
# Out:
# 1454

# %%
df[df['Description'].isnull()]
# Out:
#          index InvoiceNo StockCode Description  Quantity      InvoiceDate  \
# 622        622    536414     22139         NaN        56  12/1/2010 11:52
# 1970      1970    536545     21134         NaN         1  12/1/2010 14:32
# 1971      1971    536546     22145         NaN         1  12/1/2010 14:33
# 1972      1972    536547     37509         NaN         1  12/1/2010 14:33
# 1987      1987    536549    85226A         NaN         1  12/1/2010 14:34
# ...        ...       ...       ...         ...       ...              ...
# 535322  535322    581199     84581         NaN        -2  12/7/2011 18:26
# 535326  535326    581203     23406         NaN        15  12/7/2011 18:31
# 535332  535332    581209     21620         NaN         6  12/7/2011 18:35
# 536981  536981    581234     72817         NaN        27  12/8/2011 10:33
# 538554  538554    581408     85175         NaN        20  12/8/2011 14:06
#
#         UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Quantity Column

# %%
df[df['Quantity'] > 0].head()
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df[df['Quantity'] < 0].head()
# Out:
#      index InvoiceNo StockCode                       Description  Quantity  \
# 141    141   C536379         D                          Discount        -1
# 154    154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235    235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236    236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237    237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# 141   12/1/2010 9:41      27.50     14527.0  United Kingdom
# 154   12/1/2010 9:49       4.65     15311.0  United Kingdom
# 235  12/1/2010 10:24       1.65     17548.0  United Kingdom
# 236  12/1/2010 10:24       0.29     17548.0  United Kingdom
# 237  12/1/2010 10:24       0.29     17548.0  United Kingdom

# %%
# count of positive values in Quantity Column

pos_values = 0
neg_values = 0

for i in df['Quantity']:
  if i > 0:
    pos_values += 1
  else:
    neg_values += 1

pos_values, neg_values
# Out:
# (531285, 10624)

# %%
df.sort_values(by = ['Quantity', 'InvoiceDate'])
# Out:
#          index InvoiceNo StockCode                          Description  \
# 540422  540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE
# 61624    61624   C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 225529  225529    556690     23005         printing smudges/thrown away
# 225530  225530    556691     23005         printing smudges/thrown away
# 4287      4287   C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR
# ...        ...       ...       ...                                  ...
# 421632  421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS
# 74614    74614    542504     37413                                  NaN
# 502122  502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS
# 61619    61619    541431     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 540421  540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE
#
#         Quantity       InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.iloc[[540421, 540422],:]
# Out:
#          index InvoiceNo StockCode                  Description  Quantity  \
# 540421  540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
# 540422  540422   C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom
# 540422  12/9/2011 9:27       2.08     16446.0  United Kingdom

# %% [markdown]
# # InvoiceDate Column

# %%
df.InvoiceDate.unique()
# Out:
# array(['12/1/2010 8:26', '12/1/2010 8:28', '12/1/2010 8:34', ...,
#        '12/9/2011 12:31', '12/9/2011 12:49', '12/9/2011 12:50'],
#       dtype=object)

# %%
len(df.InvoiceDate.unique())
# Out:
# 23260

# %% [markdown]
# # UnitPrice Column

# %%
df.sort_values(by = ['UnitPrice']).head()
# Out:
#          index InvoiceNo StockCode        Description  Quantity  \
# 299984  299984   A563187         B    Adjust bad debt         1
# 299983  299983   A563186         B    Adjust bad debt         1
# 40984    40984    539750     22652  TRAVEL SEWING KIT         1
# 52217    52217    540696    84562A                NaN         1
# 52262    52262    540699      POST                NaN      1000
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 299984   8/12/2011 14:52  -11062.06         NaN  United Kingdom
# 299983   8/12/2011 14:51  -11062.06         NaN  United Kingdom
# 40984   12/21/2010 15:40       0.00         NaN  United Kingdom
# 52217     1/11/2011 9:14       0.00         NaN  United Kingdom
# 52262     1/11/2011 9:32       0.00         NaN  United Kingdom

# %% [markdown]
# # CustomerID Column

# %%
df['CustomerID'].value_counts()
# Out:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
len(df['CustomerID'].value_counts())
# Out:
# 4372

# %%
df['CustomerID'].isnull().sum()
# Out:
# 135080

# %%
df[df['CustomerID'].isnull()].head()
# Out:
#       index InvoiceNo StockCode                      Description  Quantity  \
# 622     622    536414     22139                              NaN        56
# 1443   1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444   1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445   1445    536544     21786               POLKADOT RAIN HAT          4
# 1446   1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 622   12/1/2010 11:52       0.00         NaN  United Kingdom
# 1443  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1444  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1445  12/1/2010 14:32       0.85         NaN  United Kingdom
# 1446  12/1/2010 14:32       1.66         NaN  United Kingdom

# %% [markdown]
# # Country Column

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %% [markdown]
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼

# %% [markdown]
# # **Data Cleaning**

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (541909, 9)

# %%
df = df.drop(columns = ['index'])

# %%
df = df.rename(columns = {'UnitPrice': 'UnitPrice_GBP'})

# %%
df['Description'] = df['Description'].fillna('UNKNOWN')

# %%
df['CustomerID'] = df['CustomerID'].fillna(0)

# %%
df.iloc[[622 , 1443, 1444, 1445, 1446],:]
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                          UNKNOWN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice_GBP  CustomerID         Country
# 622   12/1/2010 11:52           0.00         0.0  United Kingdom
# 1443  12/1/2010 14:32           2.51         0.0  United Kingdom
# 1444  12/1/2010 14:32           2.51         0.0  United Kingdom
# 1445  12/1/2010 14:32           0.85         0.0  United Kingdom
# 1446  12/1/2010 14:32           1.66         0.0  United Kingdom

# %%
df = df.astype({'CustomerID': 'int'})
df = df.astype({'CustomerID': 'str'})

# %%
df = df.replace({'CustomerID': {'0': 'A' + df['InvoiceNo']}})

# %%
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#       InvoiceDate  UnitPrice_GBP CustomerID         Country
# 0  12/1/2010 8:26           2.55      17850  United Kingdom
# 1  12/1/2010 8:26           3.39      17850  United Kingdom
# 2  12/1/2010 8:26           2.75      17850  United Kingdom

# %%
df.iloc[[622 , 1443, 1444, 1445, 1446],:]
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                          UNKNOWN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice_GBP CustomerID         Country
# 622   12/1/2010 11:52           0.00    A536414  United Kingdom
# 1443  12/1/2010 14:32           2.51    A536544  United Kingdom
# 1444  12/1/2010 14:32           2.51    A536544  United Kingdom
# 1445  12/1/2010 14:32           0.85    A536544  United Kingdom
# 1446  12/1/2010 14:32           1.66    A536544  United Kingdom

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df['InvoiceDate'].dt.year.value_counts()
# Out:
# 2011    499428
# 2010     42481
# Name: InvoiceDate, dtype: int64

# %%
df = df[df['InvoiceDate'].dt.year == 2011]

# %% [markdown]
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# # Price_GBP Column

# %%
df['Price_GBP'] = df['Quantity'] * df['UnitPrice_GBP']

# %% [markdown]
# # InvoiceDate and Price_GBP Column

# %%
# df['Year_Month']  = df['InvoiceDate'].apply(lambda x: x.strftime('%B-%Y'))
# df['Year_Month']  = pd.to_datetime(df['Year_Month'], format = '%B-%Y')
# df['Year']        = df['InvoiceDate'].dt.year.astype('str')

# %%
df['Month']       = df['InvoiceDate'].dt.month_name()
df['Day']         = df['InvoiceDate'].dt.day_name()
df['Hour']        = df['InvoiceDate'].dt.hour

# %%
df.head()
# Out:
#       InvoiceNo StockCode                Description  Quantity  \
# 42481    539993     22386    JUMBO BAG PINK POLKADOT        10
# 42482    539993     21499         BLUE POLKADOT WRAP        25
# 42483    539993     21498        RED RETROSPOT WRAP         25
# 42484    539993     22379   RECYCLING BAG RETROSPOT          5
# 42485    539993     20718  RED RETROSPOT SHOPPER BAG        10
#
#               InvoiceDate  UnitPrice_GBP CustomerID         Country  \
# 42481 2011-01-04 10:00:00           1.95      13313  United Kingdom
# 42482 2011-01-04 10:00:00           0.42      13313  United Kingdom
# 42483 2011-01-04 10:00:00           0.42      13313  United Kingdom
# 42484 2011-01-04 10:00:00           2.10      13313  United Kingdom
# 42485 2011-01-04 10:00:00           1.25      13313  United Kingdom
#
#        Price_GBP    Month      Day  Hour
# 42481       19.5  January  Tuesday    10
# 42482       10.5  January  Tuesday    10
# 42483       10.5  January  Tuesday    10
# ...

# %% [markdown]
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# # Country

# %%
countries = pd.DataFrame(df['Country'].value_counts()).reset_index()
countries = countries.rename(columns = {'index': 'Country', 'Country': 'CountOfCountry'})
countries = countries[countries['CountOfCountry'] < 500]

df['Country'] = df['Country'].apply(
    lambda x: 'Other' if x in list(countries['Country']) else x
)

# %%
df['Country'].value_counts()
# Out:
# United Kingdom     455353
# Germany              8930
# France               8118
# EIRE                 7793
# Other                4268
# Spain                2458
# Netherlands          2299
# Belgium              1974
# Switzerland          1953
# Portugal             1399
# Australia            1224
# Norway                939
# Italy                 762
# Channel Islands       741
# Finland               678
# Cyprus                539
# Name: Country, dtype: int64

# %%
# cols = ['InvoiceNo', 'StockCode', 'InvoiceDate', 'Description', 'CustomerID',
#         'Quantity', 'UnitPrice_GBP', 'Price_GBP', 'Country',
#         'Month_Year', 'Year', 'Month', 'Day', 'Weekday', 'Hour']

# df = df.reindex(columns = cols)

# %% [markdown]
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼

# %% [markdown]
# # **Data Analysis**

# %% [markdown]
# # Sales VS Time

# %%
# sales_year_month = df.groupby('Year_Month')[['Price_GBP']].sum().reset_index()
# sales_year_month

# %%
# sales_year = df.groupby('Year')[['Price_GBP']].sum().reset_index()
# sales_year

# %%
sales_month = df.groupby('Month')[['Price_GBP']].sum().reset_index()
month_list  = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales_month.index = pd.CategoricalIndex(sales_month['Month'], categories = month_list, ordered = True)
sales_month = sales_month.sort_index().reset_index(drop = True)
sales_month
# Out:
#         Month    Price_GBP
# 0     January   560000.260
# 1    February   498062.650
# 2       March   683267.080
# 3       April   493207.121
# 4         May   723333.510
# 5        June   691123.120
# 6        July   681300.111
# 7      August   682680.510
# 8   September  1019687.622
# 9     October  1070704.670
# 10   November  1461756.250
# 11   December   433668.010

# %%
sales_day = df.groupby('Day')[['Price_GBP']].sum().reset_index()
day_list  = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
sales_day.index = pd.CategoricalIndex(sales_day['Day'], categories = day_list, ordered = True)
sales_day = sales_day.sort_index().reset_index(drop = True)
sales_day
# Out:
#          Day    Price_GBP
# 0     Sunday   749536.711
# 1     Monday  1474628.161
# 2    Tuesday  1831182.511
# 3  Wednesday  1595743.350
# 4   Thursday  1953648.930
# 5     Friday  1394051.251

# %%
sales_hour = df.groupby('Hour')[['Price_GBP']].sum().reset_index()
sales_hour
# Out:
#     Hour    Price_GBP
# 0      6     -497.350
# 1      7    30542.320
# 2      8   275697.830
# 3      9   706609.601
# 4     10  1245066.951
# 5     11  1063969.780
# 6     12  1278351.170
# 7     13  1092389.000
# 8     14   992998.771
# 9     15  1066294.300
# 10    16   650950.350
# 11    17   407560.911
# 12    18   130762.610
# 13    19    42374.940
# 14    20    15719.730

# %% [markdown]
# # Sales by Country

# %%
countries = pd.DataFrame(df.groupby(['Country']).agg({'Price_GBP': [np.sum, np.mean]}))
countries = countries.reset_index()
countries = countries.sort_values(by = [('Price_GBP', 'sum')], ascending = False)
countries
# Out:
#             Country    Price_GBP
#                              sum        mean
# 15   United Kingdom  7511063.744   16.495035
# 9       Netherlands   275877.060  119.998721
# 4              EIRE   254246.870   32.625031
# 7           Germany   207135.370   23.195450
# 6            France   187828.540   23.137292
# 11            Other   152483.410   35.727134
# 0         Australia   136072.170  111.170074
# 14      Switzerland    55080.430   28.202985
# 13            Spain    52930.850   21.534113
# 1           Belgium    39101.050   19.808029
# 10           Norway    31376.340   33.414633
# 12         Portugal    26986.900   19.290136
# 5           Finland    21433.940   31.613481
# 2   Channel Islands    19722.760   26.616410
# 8             Italy    16096.010   21.123373
# 3            Cyprus    11355.470   21.067662

# %%
countries.columns
# Out:
# MultiIndex([(  'Country',     ''),
#             ('Price_GBP',  'sum'),
#             ('Price_GBP', 'mean')],
#            )

# %%
countries[('Price_GBP', 'sum')]
# Out:
# 15    7511063.744
# 9      275877.060
# 4      254246.870
# 7      207135.370
# 6      187828.540
# 11     152483.410
# 0      136072.170
# 14      55080.430
# 13      52930.850
# 1       39101.050
# 10      31376.340
# 12      26986.900
# 5       21433.940
# 2       19722.760
# 8       16096.010
# 3       11355.470
# Name: (Price_GBP, sum), dtype: float64

# %%
countries.index[countries['Country'] == 'United Kingdom'].to_list()
# Out:
# [15]

# %% [markdown]
# # Sales by Customer

# %%
customers = pd.DataFrame()
customers['Price_GBP'] = pd.DataFrame(df.groupby('CustomerID')['Price_GBP'].sum())
customers = customers.reset_index()
customers = customers.sort_values(by = 'Price_GBP', ascending = False)

# %%
customers
# Out:
#      CustomerID  Price_GBP
# 1663      14646  270897.14
# 4111      18102  228603.88
# 3659      17450  185453.33
# 1851      14911  125815.49
# 55        12415  123725.45
# ...         ...        ...
# 7471   AA563186  -11062.06
# 7635   AC580604  -11586.50
# 7474   AC540118  -16453.71
# 7473   AC540117  -16888.02
# 7636   AC580605  -17836.46
#
# [7637 rows x 2 columns]

# %% [markdown]
# # StockCode (Product Analysis)

# %%
stock_code = df.groupby('StockCode')[['Price_GBP']].sum().reset_index().sort_values(by = ['Price_GBP'], ascending = False)

# %%
stock_code
# Out:
#          StockCode   Price_GBP
# 3983           DOT  181574.290
# 1323         22423  137864.830
# 2696         47566   97095.240
# 3474        85123A   88815.540
# 3454        85099B   88383.680
# ...            ...         ...
# 3964  BANK CHARGES   -6128.339
# 3966          CRUK   -7933.430
# 3963             B  -11062.060
# 3984             M  -68620.280
# 3962     AMAZONFEE -182277.420
#
# [3993 rows x 2 columns]

# %% [markdown]
# # Sales & Countries & Time

# %%
# df.groupby(['Year', 'Country'])[['Price_GBP']].sum()

# %%
df.groupby(['Month', 'Country'])[['Price_GBP']].sum()
# Out:
#                             Price_GBP
# Month     Country
# April     Australia           333.400
#           Belgium            1954.150
#           Channel Islands     293.000
#           Cyprus              -35.800
#           EIRE               7570.500
# ...                               ...
# September Other             11510.320
#           Portugal           1433.220
#           Spain              5163.740
#           Switzerland        8254.960
#           United Kingdom   862018.152
#
# [182 rows x 1 columns]

# %% [markdown]
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# # Sales by Country

# %%
# display sales by each country

plt.figure(figsize = (20,5))
plt.bar(countries['Country'], countries[('Price_GBP', 'sum')], width = 0.5)
plt.xticks(rotation = 20)
plt.ylabel('Sales in millions [GBP]', fontsize = 12)
plt.title('Sales in millions [GBP] per Country', fontsize = 20)
plt.show()

# %%
# exclude United Kingdom from graph to comparine other countries

plt.figure(figsize = (20,5))
plt.bar(countries['Country'].drop([15]), countries[('Price_GBP',  'sum')].drop([15]))
plt.xticks(rotation = 20)
plt.ylabel('Sales in [GBP]', fontsize = 12)
plt.title('Sales in [GBP] per Country', fontsize = 20)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# # Sales by Time

# %%
# sales by month

plt.figure(figsize = (20,5))
plt.plot(sales_month['Month'], sales_month['Price_GBP'])
plt.ylabel('Sales in millions [GBP]', fontsize = 12)
plt.title('Sales Per Month', fontsize = 20)
plt.grid()
plt.show()

# %%
# sales by day

plt.figure(figsize = (20,5))
plt.plot(sales_day['Day'], sales_day['Price_GBP'])
plt.ylabel('Sales in millions [GBP]', fontsize = 12)
plt.title('Sales Per Day', fontsize = 20)
plt.grid()
plt.show()

# %%
# sales by hour

plt.figure(figsize = (20,5))
x, y = sales_hour['Hour'], sales_hour['Price_GBP']
XY_Spline = make_interp_spline(x, y)
X = np.linspace(x.min(), x.max(), 500)
Y = XY_Spline(X)
plt.plot(X, Y)
plt.xlabel('Hour', fontsize = 12)
plt.ylabel('Sales in millions [GBP]', fontsize = 12)
plt.title('Sales Per Hour', fontsize = 20)
plt.grid()
plt.show()

# %% [markdown]
# # Top Customers

# %%
plt.figure(figsize = (20,5))
plt.bar(customers['CustomerID'][0:30],customers['Price_GBP'][0:30])
plt.xticks(rotation = 20)
plt.xlabel('Customer ID', fontsize = 12)
plt.ylabel('Sales in [GBP]', fontsize = 12)
plt.title('Top Customers', fontsize = 20)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# # Top Products

# %%
plt.figure(figsize = (20,5))
plt.bar(stock_code['StockCode'][0:30],stock_code['Price_GBP'][0:30])
plt.xticks(rotation = 20)
plt.xlabel('Product ID', fontsize = 12)
plt.ylabel('Sales in [GBP]', fontsize = 12)
plt.title('Top Products', fontsize = 20)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼
